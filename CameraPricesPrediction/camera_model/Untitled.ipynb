# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Camera.csv",delimiter=";")
df.columns = [c.replace(' ', '_') for c in df.columns]
df.columns = [c.replace('.', '').replace('.','').replace('(','').replace(')','') for c in df.columns]
df.Model
# Out:
#                        Model Release_date Max_resolution Low_resolution  \
# 0                     STRING       DOUBLE         DOUBLE         DOUBLE
# 1           Agfa ePhoto 1280         1997         1024.0          640.0
# 2           Agfa ePhoto 1680         1998         1280.0          640.0
# 3           Agfa ePhoto CL18         2000          640.0            0.0
# 4           Agfa ePhoto CL30         1999         1152.0          640.0
# 5     Agfa ePhoto CL30 Clik!         1999         1152.0          640.0
# 6           Agfa ePhoto CL45         2001         1600.0          640.0
# 7           Agfa ePhoto CL50         1999         1280.0          640.0
# 8        Canon PowerShot 350         1997          640.0            0.0
# 9        Canon PowerShot 600         1996          832.0          640.0
# 10       Canon PowerShot A10         2001         1280.0         1024.0
# 11      Canon PowerShot A100         2002         1280.0         1024.0
# 12       Canon PowerShot A20         2001         1600.0         1024.0
# 13      Canon PowerShot A200         2002         1600.0         1024.0
# 14       Canon PowerShot A30         2002         1280.0         1024.0
# 15      Canon PowerShot A300         2003         2048.0         1600.0
# 16      Canon PowerShot A310         2004         2048.0         1600.0
# 17       Canon PowerShot A40         2002         1600.0         1024.0
# 18      Canon PowerShot A400         2004         2048.0         1600.0
# 19      Canon PowerShot A410         2005         2048.0         1600.0
# 20      Canon PowerShot A420         2006         2272.0         1600.0
# 21      Canon PowerShot A430         2006         2272.0         1600.0
# 22      Canon PowerShot A450         2007         2592.0         2048.0
# 23      Canon PowerShot A460         2007         2592.0         2048.0
# 24        Canon PowerShot A5         1998         1024.0          512.0
# 25       Canon PowerShot A50         1999         1280.0          640.0
# 26      Canon PowerShot A510         2005         2048.0         1600.0
# 27      Canon PowerShot A520         2005         2272.0         1600.0
# 28      Canon PowerShot A530         2006         2592.0         2048.0
# 29      Canon PowerShot A540         2006         2816.0         2272.0
# ...                      ...          ...            ...            ...
# 1009       Sony Mavica FD-71         1998          640.0          320.0
# 1010       Sony Mavica FD-73         1999          640.0          320.0
# 1011       Sony Mavica FD-75         2001          640.0          320.0
# 1012       Sony Mavica FD-81         1998         1024.0          640.0
# 1013       Sony Mavica FD-83         1999         1024.0          640.0
# 1014       Sony Mavica FD-85         2000         1280.0         1280.0
# 1015       Sony Mavica FD-87         2001         1280.0         1024.0
# 1016       Sony Mavica FD-88         1999         1280.0         1024.0
# 1017       Sony Mavica FD-90         2000         1280.0         1280.0
# 1018       Sony Mavica FD-92         2001         1472.0         1280.0
# 1019       Sony Mavica FD-95         2000         1600.0         1600.0
# 1020       Sony Mavica FD-97         2001         1600.0         1024.0
# 1021        Toshiba PDR-3310         2002         2048.0         1024.0
# 1022        Toshiba PDR-3330         2002         2048.0         1024.0
# 1023        Toshiba PDR-4300         2003         2400.0         1200.0
# 1024        Toshiba PDR-5300         2003         2560.0         2048.0
# 1025          Toshiba PDR-M1         1998         1280.0          640.0
# 1026         Toshiba PDR-M11         2001         1280.0          640.0
# 1027         Toshiba PDR-M21         2001         1600.0          800.0
# 1028         Toshiba PDR-M25         2001         1729.0          896.0
# 1029          Toshiba PDR-M3         1999         1280.0          640.0
# 1030          Toshiba PDR-M4         1999         1600.0          800.0
# 1031          Toshiba PDR-M5         1999         1600.0          800.0
# 1032         Toshiba PDR-M60         2000         1792.0          896.0
# 1033         Toshiba PDR-M61         2001         1792.0          896.0
# 1034         Toshiba PDR-M65         2001         2048.0         1024.0
# 1035         Toshiba PDR-M70         2000         2048.0         1024.0
# 1036         Toshiba PDR-M71         2001         2048.0         1024.0
# 1037         Toshiba PDR-M81         2001         2400.0         1200.0
# 1038         Toshiba PDR-T10         2002         1600.0          800.0
#
#      Effective_pixels Zoom_wide_W Zoom_tele_T Normal_focus_range  \
# 0              DOUBLE      DOUBLE      DOUBLE             DOUBLE
# 1                 0.0        38.0       114.0               70.0
# 2                 1.0        38.0       114.0               50.0
# 3                 0.0        45.0        45.0                0.0
# 4                 0.0        35.0        35.0                0.0
# 5                 0.0        43.0        43.0               50.0
# 6                 1.0        51.0        51.0               50.0
# 7                 1.0        34.0       102.0                0.0
# 8                 0.0        42.0        42.0               70.0
# 9                 0.0        50.0        50.0               40.0
# 10                1.0        35.0       105.0               76.0
# 11                1.0        39.0        39.0               20.0
# 12                1.0        35.0       105.0               76.0
# 13                1.0        39.0        39.0               20.0
# 14                1.0        35.0       105.0               76.0
# 15                3.0        33.0        33.0               20.0
# 16                3.0        33.0        33.0                0.0
# 17                1.0        35.0       105.0               76.0
# 18                3.0        45.0       100.0                0.0
# 19                3.0        41.0       131.0                0.0
# 20                4.0        39.0       125.0               47.0
# 21                4.0        39.0       156.0               47.0
# 22                5.0        38.0       122.0               47.0
# 23                5.0        38.0       152.0               47.0
# 24                0.0        35.0        35.0               50.0
# 25                1.0        28.0        70.0               50.0
# 26                3.0        35.0       140.0                0.0
# 27                3.0        35.0       140.0                0.0
# 28                5.0        35.0       140.0               45.0
# 29                6.0        35.0       140.0               45.0
# ...               ...         ...         ...                ...
# 1009              0.0        40.0       400.0                1.0
# 1010              0.0        40.0       400.0                1.0
# 1011              0.0        40.0       400.0                1.0
# 1012              0.0        37.0       111.0                1.0
# 1013              0.0        37.0       111.0                1.0
# 1014              1.0        37.0       111.0                1.0
# 1015              1.0        39.0       117.0               25.0
# 1016              1.0        34.0       270.0                4.0
# 1017              1.0        34.0       270.0                4.0
# 1018              1.0        41.0       328.0               25.0
# 1019              1.0        37.0       370.0               80.0
# 1020              1.0        39.0       390.0               25.0
# 1021              3.0        35.0       105.0               55.0
# 1022              3.0        35.0       100.0               80.0
# 1023              3.0        35.0       100.0               80.0
# 1024              4.0        35.0       105.0               80.0
# 1025              1.0        35.0        35.0               50.0
# 1026              1.0        52.0        52.0               90.0
# 1027              1.0        39.0        39.0               50.0
# 1028              2.0        38.0       114.0               40.0
# 1029              1.0        38.0       115.0               90.0
# 1030              1.0        40.0        40.0               50.0
# 1031              1.0        40.0       120.0               90.0
# 1032              2.0        38.0        86.0               50.0
# 1033              2.0        38.0       114.0               50.0
# 1034              3.0        38.0       114.0               10.0
# 1035              3.0        35.0       105.0               80.0
# 1036              3.0        35.0        98.0               80.0
# 1037              3.0        35.0        98.0               80.0
# 1038              1.0        38.0        38.0               40.0
#
#      Macro_focus_range Storage_included Weight_inc_batteries Dimensions  \
# 0               DOUBLE           DOUBLE               DOUBLE     DOUBLE
# 1                 40.0              4.0                420.0       95.0
# 2                  0.0              4.0                420.0      158.0
# 3                  0.0              2.0                  0.0        0.0
# 4                  0.0              4.0                  0.0        0.0
# 5                  0.0             40.0                300.0      128.0
# 6                 20.0              8.0                270.0      119.0
# 7                  0.0              8.0                  0.0        0.0
# 8                  3.0              2.0                320.0       93.0
# 9                 10.0              1.0                460.0      160.0
# 10                16.0              8.0                375.0      110.0
# 11                 5.0              8.0                225.0      110.0
# 12                16.0              8.0                375.0      110.0
# 13                 5.0              8.0                225.0      110.0
# 14                16.0              8.0                350.0      110.0
# 15                 5.0             32.0                225.0      111.0
# 16                 5.0              0.0                205.0      110.0
# 17                16.0              8.0                350.0      110.0
# 18                 5.0             16.0                255.0      107.0
# 19                 1.0             16.0                195.0      103.0
# 20                 1.0             16.0                200.0      103.0
# 21                 1.0             16.0                210.0      103.0
# 22                 1.0             16.0                215.0      106.0
# 23                 1.0             16.0                215.0      106.0
# 24                 9.0              8.0                240.0      105.0
# 25                17.0              8.0                290.0      103.0
# 26                 5.0             16.0                230.0       91.0
# 27                 5.0             16.0                230.0       91.0
# 28                 5.0             16.0                220.0       90.0
# 29                 5.0             16.0                230.0       90.0
# ...                ...              ...                  ...        ...
# 1009               1.0              1.0                500.0      138.0
# 1010               1.0              1.0                500.0      138.0
# 1011               1.0              1.0                580.0      138.0
# 1012               1.0              1.0                580.0      140.0
# 1013               1.0              1.0                580.0      142.0
# 1014               1.0              1.0                  0.0        0.0
# 1015               3.0              1.0                630.0      143.0
# 1016               4.0              1.0                600.0      142.0
# 1017               4.0              1.0                  0.0        0.0
# 1018               3.0              1.0                660.0      126.0
# 1019               3.0              1.0                900.0        0.0
# 1020               2.0              1.0                990.0      126.0
# 1021              12.0              8.0                205.0       91.0
# 1022              10.0              8.0                320.0      116.0
# 1023              10.0             16.0                  0.0        0.0
# 1024              10.0             16.0                230.0       93.0
# 1025               9.0              4.0                290.0      123.0
# 1026               0.0              8.0                240.0      116.0
# 1027               0.0              8.0                240.0      116.0
# 1028               8.0              8.0                320.0      105.0
# 1029              25.0              4.0                380.0      122.0
# 1030              10.0              8.0                290.0      112.0
# 1031              25.0              8.0                350.0      130.0
# 1032               5.0              4.0                320.0      121.0
# 1033               5.0              8.0                310.0      123.0
# 1034              10.0              8.0                320.0      120.0
# 1035               9.0             16.0                390.0      116.0
# 1036              10.0              8.0                340.0      107.0
# 1037              10.0             16.0                340.0      107.0
# 1038              20.0              8.0                180.0       86.0
#
#        Price
# 0     DOUBLE
# 1      179.0
# 2      179.0
# 3      179.0
# 4      269.0
# 5     1299.0
# 6      179.0
# 7      179.0
# 8      149.0
# 9      139.0
# 10     139.0
# 11     139.0
# 12     139.0
# 13     139.0
# 14     139.0
# 15     139.0
# 16     139.0
# 17     139.0
# 18     139.0
# 19     139.0
# 20     139.0
# 21     139.0
# 22     139.0
# 23     139.0
# 24     149.0
# 25     149.0
# 26     139.0
# 27     149.0
# 28     149.0
# 29     149.0
# ...      ...
# 1009  1399.0
# 1010  1399.0
# 1011  1399.0
# 1012  1399.0
# 1013  1399.0
# 1014  1399.0
# 1015  1399.0
# 1016  1399.0
# 1017  1399.0
# 1018  1399.0
# 1019  1399.0
# 1020  1399.0
# 1021   177.0
# 1022   177.0
# 1023   599.0
# 1024   177.0
# 1025    62.0
# 1026    62.0
# 1027   177.0
# 1028   177.0
# 1029    62.0
# 1030    62.0
# 1031    62.0
# 1032   449.0
# 1033    62.0
# 1034    62.0
# 1035    62.0
# 1036    62.0
# 1037    62.0
# 1038   129.0
#
# [1039 rows x 13 columns]

# %%
num_epochs=2000

# %%
train=df.sample(frac=0.8,random_state=200)
test=df.drop(train.index)

# %%
FEATURES=df.columns.values.tolist()

# %%
feature_cols = [tf.feature_column.numeric_column(k,dtype=tf.float32)  for k in FEATURES]
feature_cols
# Out:
# [_NumericColumn(key='Model', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Release_date', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Max_resolution', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Low_resolution', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Effective_pixels', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Zoom_wide_W', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Zoom_tele_T', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Normal_focus_range', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Macro_focus_range', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Storage_included', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Weight_inc_batteries', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Dimensions', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Price', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
regressor = tf.contrib.learn.DNNRegressor(hidden_units=[10, 10],feature_columns=feature_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\bkaushal\AppData\Local\Temp\tmpn10u0tzw
# INFO:tensorflow:Using config: {'_is_chief': True, '_keep_checkpoint_max': 5, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000000D7E7208>, '_tf_random_seed': None, '_save_checkpoints_steps': None, '_evaluation_master': '', '_task_type': None, '_model_dir': 'C:\\Users\\bkaushal\\AppData\\Local\\Temp\\tmpn10u0tzw', '_num_ps_replicas': 0, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_session_config': None, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# }

# %%
def get_input_fn(train, num_epochs=None, shuffle=True):
  return tf.estimator.inputs.pandas_input_fn(
      x=train,
      y = train.Price,
      num_epochs=num_epochs,
      shuffle=shuffle)

# %%
regressor.fit(input_fn=get_input_fn(train),steps=5000,)
# Out:
# WARNING:tensorflow:From c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Error reported to Coordinator: <class 'SystemError'>, <built-in function TF_Run> returned a result with an error set
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#
# ~\AppData\Local\Programs\Python\Python35\Lib\contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# UnimplementedError: Cast string to float is not supported
# 	 [[Node: dnn/input_from_feature_columns/input_layer/Dimensions/ToFloat = Cast[DstT=DT_FLOAT, SrcT=DT_STRING, _device="/job:localhost/replica:0/task:0/cpu:0"](dnn/input_from_feature_columns/input_layer/Dimensions/ExpandDims)]]
#
# During handling of the above exception, another exception occurred:
#
# UnimplementedError                        Traceback (most recent call last)
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in _train_model(self, input_fn, hooks)
#    1006         while not mon_sess.should_stop():
# -> 1007           _, loss = mon_sess.run([model_fn_ops.train_op, model_fn_ops.loss])
#    1008       summary_io.SummaryWriterCache.clear()
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     504                           options=options,
# --> 505                           run_metadata=run_metadata)
#     506
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     841                               options=options,
# --> 842                               run_metadata=run_metadata)
#     843       except _PREEMPTION_ERRORS as e:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, *args, **kwargs)
#     797   def run(self, *args, **kwargs):
# --> 798     return self._sess.run(*args, **kwargs)
#     799
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     951                                   options=options,
# --> 952                                   run_metadata=run_metadata)
#     953
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, *args, **kwargs)
#     797   def run(self, *args, **kwargs):
# --> 798     return self._sess.run(*args, **kwargs)
#     799
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1151           pass
# -> 1152       raise type(e)(node_def, op, message)
#    1153
#
# UnimplementedError: Cast string to float is not supported
# 	 [[Node: dnn/input_from_feature_columns/input_layer/Dimensions/ToFloat = Cast[DstT=DT_FLOAT, SrcT=DT_STRING, _device="/job:localhost/replica:0/task:0/cpu:0"](dnn/input_from_feature_columns/input_layer/Dimensions/ExpandDims)]]
#
# Caused by op 'dnn/input_from_feature_columns/input_layer/Dimensions/ToFloat', defined at:
#   File "C:\Users\bkaushal\AppData\Local\Programs\Python\Python35\Lib\runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\bkaushal\AppData\Local\Programs\Python\Python35\Lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\IPython\core\interactiveshell.py", line 2808, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-206-f9619aac7583>", line 1, in <module>
#     regressor.fit(input_fn=get_input_fn(train),steps=5000,)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\util\deprecation.py", line 289, in new_func
#     return func(*args, **kwargs)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py", line 455, in fit
#     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py", line 955, in _train_model
#     model_fn_ops = self._get_train_ops(features, labels)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py", line 1162, in _get_train_ops
#     return self._call_model_fn(features, labels, model_fn_lib.ModeKeys.TRAIN)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py", line 1133, in _call_model_fn
#     model_fn_results = self._model_fn(features, labels, **kwargs)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\dnn.py", line 143, in _dnn_model_fn
#     weight_collections=[parent_scope])
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 230, in input_layer
#     trainable=trainable)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 1651, in _get_dense_tensor
#     return inputs.get(self)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 1460, in get
#     transformed = column._transform_feature(self)  # pylint: disable=protected-access
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 1626, in _transform_feature
#     return math_ops.to_float(input_tensor)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\ops\math_ops.py", line 738, in to_float
#     return cast(x, dtypes.float32, name=name)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\ops\math_ops.py", line 689, in cast
#     return gen_math_ops.cast(x, base_type, name=name)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 403, in cast
#     result = _op_def_lib.apply_op("Cast", x=x, DstT=DstT, name=name)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\framework\ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\framework\ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# UnimplementedError (see above for traceback): Cast string to float is not supported
# 	 [[Node: dnn/input_from_feature_columns/input_layer/Dimensions/ToFloat = Cast[DstT=DT_FLOAT, SrcT=DT_STRING, _device="/job:localhost/replica:0/task:0/cpu:0"](dnn/input_from_feature_columns/input_layer/Dimensions/ExpandDims)]]
#
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-206-f9619aac7583> in <module>()
# ----> 1 regressor.fit(input_fn=get_input_fn(train),steps=5000,)
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     287             'in a future version' if date is None else ('after %s' % date),
#     288             instructions)
# --> 289       return func(*args, **kwargs)
#     290     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     291                                        _add_deprecated_arg_notice_to_docstring(
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     453       hooks.append(basic_session_run_hooks.StopAtStepHook(steps, max_steps))
#     454
# --> 455     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     456     logging.info('Loss for final step: %s.', loss)
#     457     return self
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in _train_model(self, input_fn, hooks)
#    1005         loss = None
#    1006         while not mon_sess.should_stop():
# -> 1007           _, loss = mon_sess.run([model_fn_ops.train_op, model_fn_ops.loss])
#    1008       summary_io.SummaryWriterCache.clear()
#    1009       return loss
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in __exit__(self, exception_type, exception_value, traceback)
#     519     if exception_type in [errors.OutOfRangeError, StopIteration]:
#     520       exception_type = None
# --> 521     self._close_internal(exception_type)
#     522     # __exit__ should return True to suppress an exception.
#     523     return exception_type is None
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in _close_internal(self, exception_type)
#     554     finally:
#     555       try:
# --> 556         self._sess.close()
#     557       finally:
#     558         self._sess = None
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in close(self)
#     789     if self._sess:
#     790       try:
# --> 791         self._sess.close()
#     792       except _PREEMPTION_ERRORS:
#     793         pass
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\monitored_session.py in close(self)
#     886       self._coord.join(
#     887           stop_grace_period_secs=self._stop_grace_period_secs,
# --> 888           ignore_live_threads=True)
#     889     finally:
#     890       try:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\training\coordinator.py in join(self, threads, stop_grace_period_secs, ignore_live_threads)
#     387       self._registered_threads = set()
#     388       if self._exc_info_to_raise:
# --> 389         six.reraise(*self._exc_info_to_raise)
#     390       elif stragglers:
#     391         if ignore_live_threads:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#     688 else:
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_queue_runner.py in _run(self, sess, enqueue_op, feed_fn, coord)
#      92         try:
#      93           feed_dict = None if feed_fn is None else feed_fn()
# ---> 94           sess.run(enqueue_op, feed_dict=feed_dict)
#      95         except (errors.OutOfRangeError, errors.CancelledError):
#      96           # This exception indicates that a queue was closed.
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# c:\users\bkaushal\aiva\stockprediction\tensordemo\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# SystemError: <built-in function TF_Run> returned a result with an error set

# %%
FEATURES
